# %% [markdown]
# Notebook para analizar las diferencias entre el reporte post operativo mensual vs el diario

# %%
#Librerias

import pandas as pd

# %%
df_m = pd.read_excel(r"Datos\VALORES_GENERADORES mensual.xlsx")

# %%
df_m.info(verbose=True, max_cols=100)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 505920 entries, 0 to 505919
# Data columns (total 33 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   FECHA                505920 non-null  datetime64[ns]
#  1   HORA                 505920 non-null  int64
#  2   GRUPO                505920 non-null  object
#  3   ARL_ECON             505920 non-null  int64
#  4   EST_REMUN            505920 non-null  object
#  5   SMEC                 505920 non-null  object
#  6   ENERGIA              505920 non-null  float64
#  7   POT_DISP             505920 non-null  float64
#  8   ENERG_OPERADA        420144 non-null  float64
#  9   POT_RECONOC          505776 non-null  float64
#  10  POT_DISP_GN          505920 non-null  float64
#  11  PIND                 421848 non-null  float64
#  12  PINDFORZ             421848 non-null  float64
#  13  PRECIO_NODO          505920 non-null  int64
# ...

# %%
df_d = pd.read_excel(r"Datos\VALORES_GENERADORES Diario.xlsx")

# %%
df_d.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16320 entries, 0 to 16319
# Data columns (total 39 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   GRUPO                16320 non-null  object
#  1   HORA                 16320 non-null  int64
#  2   ARL                  16320 non-null  int64
#  3   ESTADO_OPE           16320 non-null  object
#  4   PI_SOTR              16320 non-null  float64
#  5   ARL_ECON             16320 non-null  int64
#  6   EST_REMUN            16320 non-null  object
#  7   ENERGIA              16320 non-null  float64
#  8   PRECIO_NODO          16320 non-null  int64
#  9   PR_REM_ENERGIA       8321 non-null   float64
#  10  SMEC                 16320 non-null  object
#  11  POT_DISP             16320 non-null  float64
#  12  POT_OPE_CPO          13612 non-null  float64
#  13  COMPRA_SPOT          14232 non-null  float64
#  14  SCTD                 7654 non-null   float64
# ...

# %%
df_d.columns
# Out:
# Index(['GRUPO', 'HORA', 'ARL', 'ESTADO_OPE', 'PI_SOTR', 'ARL_ECON',
#        'EST_REMUN', 'ENERGIA', 'PRECIO_NODO', 'PR_REM_ENERGIA', 'SMEC',
#        'POT_DISP', 'POT_OPE_CPO', 'COMPRA_SPOT', 'SCTD', 'SCO', 'PIND',
#        'PINDPROG', 'PINDFORZ', 'POT_DISP_GAS', 'POT_DISP_RESERVA',
#        'GAS_NOMINADO', 'COSTO_406', 'REM_ADICIONAL', 'DESP_ECON', 'CCM', 'CFO',
#        'CGN', 'CGO', 'POT_DISP_R19', 'FACTOR_KM', 'HORA_REPRESENTATIVA',
#        'ENERG_GEN_TRANSAC', 'ENERG_OPE_TRANSAC', 'SOBREC_FORZ_PROPIO',
#        'PGENE_RES354', 'CGU_PROPIO', 'CGU_MEM', 'CGU_GAS_CEDIDO'],
#       dtype='object')

# %%
df_m.sort_index(axis=1).columns
# Out:
# Index(['ARL_ECON', 'CGU_COMPR_OPT', 'CGU_GAS_CEDIDO', 'CGU_MEM', 'CGU_PROPIO',
#        'COMPRA_SPOT', 'COSTO_406', 'DESP_ECON', 'ENERGIA', 'ENERG_GEN_TRANSAC',
#        'ENERG_OPERADA', 'ENERG_OPE_TRANSAC', 'EST_REMUN', 'FACTOR_KM', 'FECHA',
#        'GRUPO', 'HORA', 'HORA_REPRESENTATIVA', 'PGENE_RES354', 'PIND',
#        'PINDFORZ', 'POT_DISP', 'POT_DISP_GN', 'POT_DISP_R19', 'POT_RECONOC',
#        'PRECIO_NODO', 'PR_REM_ENERGIA', 'REMUN_ADIC_6866', 'REM_ADICIONAL',
#        'SCO', 'SCTD', 'SMEC', 'SOBREC_FORZ_PROPIO'],
#       dtype='object')

# %%
df_m.head(1)
# Out:
#        FECHA  HORA     GRUPO  ARL_ECON EST_REMUN SMEC  ENERGIA  POT_DISP  \
# 0 2023-12-01     1  9JULDI01         1       lib    S      0.0       4.2
#
#    ENERG_OPERADA  POT_RECONOC  ...  CGU_COMPR_OPT  HORA_REPRESENTATIVA  \
# 0            0.0          4.2  ...            NaN                  NaN
#
#    FACTOR_KM  PGENE_RES354  SOBREC_FORZ_PROPIO  CGU_PROPIO  CGU_MEM  \
# 0        1.0           NaN                 NaN         NaN      NaN
#
#    CGU_GAS_CEDIDO  ENERG_GEN_TRANSAC  ENERG_OPE_TRANSAC
# 0             NaN                NaN                NaN
#
# [1 rows x 33 columns]

# %%
for i in df_d:
    print(i)
# Out:
# GRUPO
# HORA
# ARL
# ESTADO_OPE
# PI_SOTR
# ARL_ECON
# EST_REMUN
# ENERGIA
# PRECIO_NODO
# PR_REM_ENERGIA
# SMEC
# POT_DISP
# POT_OPE_CPO
# COMPRA_SPOT
# SCTD
# SCO
# PIND
# PINDPROG
# PINDFORZ
# POT_DISP_GAS
# POT_DISP_RESERVA
# GAS_NOMINADO
# COSTO_406
# REM_ADICIONAL
# DESP_ECON
# CCM
# CFO
# CGN
# CGO
# POT_DISP_R19
# FACTOR_KM
# HORA_REPRESENTATIVA
# ENERG_GEN_TRANSAC
# ENERG_OPE_TRANSAC
# SOBREC_FORZ_PROPIO
# PGENE_RES354
# CGU_PROPIO
# CGU_MEM
# CGU_GAS_CEDIDO

# %%
df_d.describe()
# Out:
#                HORA      ARL       PI_SOTR  ARL_ECON       ENERGIA  \
# count  16320.000000  16320.0  16320.000000   16320.0  16320.000000
# mean      12.500000      1.0     19.115680       1.0     20.785057
# std        6.922399      0.0    108.656324       0.0    100.315849
# min        1.000000      1.0      0.000000       1.0      0.000000
# 25%        6.750000      1.0      0.000000       1.0      0.000000
# 50%       12.500000      1.0      0.000000       1.0      0.000000
# 75%       18.250000      1.0      0.000000       1.0      2.570000
# max       24.000000      1.0   2639.100000       1.0   2395.790000
#
#        PRECIO_NODO  PR_REM_ENERGIA      POT_DISP   POT_OPE_CPO   COMPRA_SPOT  \
# count      16320.0     8321.000000  16320.000000  13612.000000  14232.000000
# mean        3767.0    36037.582224     62.852210     27.438029      0.591335
# std            0.0    57085.252490    173.573025    122.332805     11.453399
# ...
